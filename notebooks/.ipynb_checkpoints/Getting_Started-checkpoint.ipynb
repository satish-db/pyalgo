# %%
from openbb import obb
obb.user.preferences.output_type = "dataframe"
# Out:
# Extensions to add: benzinga@1.4.0, crypto@1.4.0, currency@1.4.0, derivatives@1.4.0, economy@1.4.1, equity@1.4.0, etf@1.4.0, federal_reserve@1.4.1, fixedincome@1.4.2, fmp@1.4.1, fred@1.4.3, index@1.4.0, intrinio@1.4.0, news@1.4.0, oecd@1.1.1, polygon@1.4.0, regulators@1.4.1, sec@1.4.2, tiingo@1.4.0, tradingeconomics@1.4.0, yfinance@1.4.2
#
# Building...

# %%
data = obb.equity.price.historical("SPY",provider = "yfinance")

# %%
print(data)
# Out:
#                   open        high         low       close    volume  dividend
# date
# 2024-04-30  508.559998  509.559998  501.980011  501.980011  77483600       0.0
# 2024-05-01  501.380005  508.190002  499.869995  500.350006  80242800       0.0
# 2024-05-02  504.149994  505.890015  499.549988  505.029999  62550200       0.0
# 2024-05-03  511.160004  512.549988  508.559998  511.290009  72756700       0.0
# 2024-05-06  513.750000  516.609985  513.299988  516.570007  47264700       0.0
# ...                ...         ...         ...         ...       ...       ...
# 2025-04-23  540.429993  545.429993  533.880005  535.419983  90590700       0.0
# 2025-04-24  536.719971  547.429993  535.450012  546.690002  64150400       0.0
# 2025-04-25  546.650024  551.049988  543.690002  550.640015  61119600       0.0
# 2025-04-28  551.390015  553.549988  545.020020  550.849976  47613800       0.0
# 2025-04-29  548.909973  555.450012  548.549988  554.320007  47684100       0.0
#
# [250 rows x 6 columns]

# %%
obb.equity.fundamental.metrics("AAPL,MSFT",provider ="yfinance").transpose()
# Out:
#                                          0                1
# symbol                                AAPL             MSFT
# market_cap                 3172817960960.0  2929285398528.0
# pe_ratio                         33.578697        31.751814
# forward_pe                       25.416365        26.357191
# peg_ratio_ttm                       2.0758           1.7466
# enterprise_to_ebitda                23.413           20.844
# earnings_growth                      0.101            0.102
# earnings_growth_quarterly            0.071            0.102
# revenue_per_share                   25.974           35.224
# revenue_growth                        0.04            0.123
# enterprise_to_revenue                8.126           11.309
# quick_ratio                          0.783            1.204
# current_ratio                        0.923            1.351
# debt_to_equity                       145.0           33.998
# gross_margin                       0.46519          0.69409
# operating_margin                   0.34459          0.45458
# ebitda_margin                      0.34706          0.54255
# profit_margin                      0.24295          0.35428
# return_on_assets                   0.22519          0.14649
# return_on_equity                    1.3652          0.34291
# dividend_yield                        0.47             0.84
# dividend_yield_5y_avg               0.0057           0.0084
# payout_ratio                        0.1571           0.2482
# book_value                           4.438           40.712
# price_to_book                    47.591255         9.678719
# enterprise_value             3215836053504    2960640442368
# overall_risk                           1.0              3.0
# audit_risk                             7.0              9.0
# board_risk                             1.0              5.0
# compensation_risk                      3.0              4.0
# shareholder_rights_risk                1.0              2.0
# beta                                 1.259              1.0
# price_return_1y                   0.247549        -0.002279
# currency                               USD              USD
